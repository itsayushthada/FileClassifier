# %% [markdown]
# # Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
root_path = "/content/drive/My Drive/Backend/"

# %%
import numpy as np
from collections import Counter

# %%
def get_data():
    filename = []
    type = []

    for x in list(os.walk(root_path+"Files/"))[0][-1]:
        filename.append(x)
        type.append(x.split(".")[-1].lower())

    print(Counter(type))
    idx = list(range(0,len(filename)))
    
    filename = np.array(filename)
    type = np.array(type)
    
    np.random.shuffle(idx)
    filename = filename[idx]
    type = type[idx]

    return filename, type

# %%
t, u = get_data()
# Out:
# Counter({'docx': 224, 'pdf': 182, 'doc': 169, 'jpg': 147, 'sldprt': 143, 'csv': 136, 'png': 117, 'cbr': 94, 'a': 78, 'pptx': 60, 'ppt': 24, 'sldasm': 19, 'gif': 2, 'jpeg': 1, 'slddrt': 1, 'slddrw': 1})

# %% [markdown]
# # Text Processing

# %%
import textwrap
import numpy as np
import tensorflow as tf

# %%
def feature_extractor(filename):
    string = ""  
    with open(filename, "rb") as file:
        string = str("{0:b}".format(int.from_bytes(file.read(), byteorder='big')))
    file.close()
    
    return list(map(lambda x:int(x,2), textwrap.wrap(string, 12))), (filename.split(".")[-1]).lower()

# %%
p_update = {
    "theta1": 0,
    "theta2": 0,
    "phi1": 0,
    "phi2": 0
}

# %%
def data_sampler(data_array, samples, min_sample_size, max_sample_size, p_update):
    
    theta1 = p_update["theta1"] + len(data_array)//2
    theta2 = p_update["theta2"] + len(data_array)//10
    
    indices = np.random.normal(loc = theta1, 
                               scale = theta2, 
                               size = (samples,1)).astype(np.int32)
    
    phi1 = p_update["phi1"] + (min_sample_size + max_sample_size)//2
    phi2 = p_update["phi2"] + np.ceil((max_sample_size - min_sample_size)/np.sqrt(samples))
    
    sizes = np.clip(np.random.normal(loc = phi1, 
                             scale = phi2, 
                             size = (samples,1)).astype(np.int32), min_sample_size, max_sample_size)
    
    param = {
                "theta1": theta1, 
                "theta2": theta2,
                "phi1": min_sample_size,
                "phi2": max_sample_size,
                "dist1": "normal",
                "dist2": "normal"
            }
    
    return np.array(list(map(lambda st,sz: data_array[st[0]:st[0]+sz[0]], indices,sizes))), param

# %%
def padding(samples, max_sample_length):
    return list(map(lambda x: np.array((x+["0"]*(max_sample_length-len(x)))[:max_sample_length]), samples))

# %% [markdown]
# # Modelling

# %%
from tensorflow.keras.layers import Layer
import tensorflow.keras.backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer,Conv1D,GRU,Dense

# %%
class MeanLayer(Layer):

    """ Identity transform layer that Flatten the result of Conv1D Layer.
    """

    def __init__(self, *args, **kwargs):
        self.is_placeholder = True
        super(MeanLayer, self).__init__(*args, **kwargs)

    def call(self, inputs):
        kl_batch = K.sqrt(K.mean(K.square(inputs), axis=-1))
        self.add_loss(K.mean(K.reshape(kl_batch, (kl_batch.shape[0], -1)), axis=-1) , inputs=kl_batch)
        return kl_batch

# %%
Time_steps=100
feature_length=4096

# %%
model=Sequential()
model.add(InputLayer(input_shape=(Time_steps, feature_length), batch_size=8))

model.add(GRU(Time_steps,return_sequences=True))
model.add(GRU(Time_steps,return_sequences=True))

model.add(Conv1D(filters=100, kernel_size=32))
model.add(Conv1D(filters=50, kernel_size=32))

model.add(MeanLayer())

model.add(Dense(16))
model.add(Dense(num_of_classes, activation="sigmoid"))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_4 (GRU)                  (8, 100, 100)             1259100
# _________________________________________________________________
# gru_5 (GRU)                  (8, 100, 100)             60300
# _________________________________________________________________
# conv1d_4 (Conv1D)            (8, 69, 100)              320100
# _________________________________________________________________
# conv1d_5 (Conv1D)            (8, 38, 50)               160050
# _________________________________________________________________
# mean_layer_2 (MeanLayer)     (8, 38)                   0
# _________________________________________________________________
# dense_4 (Dense)              (8, 16)                   624
# _________________________________________________________________
# dense_5 (Dense)              (8, 4)                    68
# =================================================================
# Total params: 1,800,242
# Trainable params: 1,800,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Feathure Extraction

# %%
min_sample_length = 50
max_sample_length = 100

# %%
file_type_dict = {
    'docx': 0, 
    'pdf': 1, 
    'doc': 2, 
    'jpg': 3,
    'gif': 3, 
    'jpeg': 3, 
    'sldprt': 4,
    'slddrt': 4, 
    'slddrw': 4,
    'sldasm': 4,
    'csv': 5, 
    'png': 6, 
    'cbr': 7, 
    'a': 8, 
    'pptx': 9, 
    'ppt': 9
}

# %%
def model_data(file_list, type_list, n_samples, min_sample_length, max_sample_length, p_update):
  data, type = [], []
  
  for i in range(len(file_list)):
      data_arr = feature_extractor(root_path + "Files/"+ file_list[i])
      feat = data_sampler(data_arr[0], n_samples, min_sample_length, max_sample_length, p_update)

      data = data + padding(feat[0], max_sample_length)
      type = type + [file_type_dict[type_list[i]]]*n_samples

  data = np.array(data)
  type = np.array(type)

  t = np.array(range(0,80))
  np.random.shuffle(t)
  
  return data[t], type[t], feat[1]

# %%
model1=model
model1.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
"""
def clone(model):
  model_copy= keras.models.clone_model(model1)
  model_copy.build((None, 10)) # replace 10 with number of variables in input layer
  model_copy.compile(optimizer='rmsprop', loss='categorical_crossentropy')
  model_copy.set_weights(model.get_weights())
"""

# %%
cost = 1e12

param = 0
model_copy = model

# %%
name = -1

# %%
from tensorflow.keras.models import load_model

# %%
mdir = list(os.walk(root_path+"Model/"))[0][-1]
if len(mdir) != 0:
    model = load_model("{}Model/{}.h5".format(root_path, name))
# Out:
# 0

# %%
datax, typex, param = 0, 0, 0
for i in range(0,len(t),10):
        datax, typex, param = model_data(
                        file_list = t[i:min(i+10, len(t))],
                        type_list = u[i:min(i+10, len(t))],
                        n_samples = 20,
                        min_sample_length = min_sample_length,
                        max_sample_length = max_sample_length,
                        p_update = p_update)
        break

# %%
for epoch in range(epochs(10)):
    for i in range(0,len(t),10):
        datax, typex, param = model_data(
                        file_list = t[i:min(i+10, len(t))],
                        type_list = u[i:min(i+10, len(t))],
                        n_samples = 20,
                        min_sample_length = min_sample_length,
                        max_sample_length = max_sample_length,
                        p_update = p_update)
          x_data = []

          for i in range(datax.shape[0]):
              x_data.append(np.eye(4096)[datax[i].astype(np.int32)])

          x_data = np.array(x_data)
          y_data = np.eye(num_of_classes)[typex]
          model_copy.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
          m=model_copy.fit(x_data,y_data)
          d=m.history["loss"]
          cc_loss=(d[0][0]+d[0][1]+d[0][2]+d[0][3])/4

          if cc_loss < cost:
              cost=cc_loss
              model=tf.keras.models.clone_model(
                model_copy,
                input_tensors=None
            )

              model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])
              model.set_weights(model_copy.get_weights())
              p_update = {
                            "theta1": np.random.randint(-10, 11),
                            "theta2": np.random.randint(-50, 51),
                            "phi1": np.random.randint(-5, 6),
                            "phi2": np.random.randint(-5, 6)
                            }


        if i%50==0 and i!=0:
          print(i, "model Saved.....\n\n\n")
          model.save(root_path + '/Model/my_model{}.h5'.format((name + 1)%5)
# Out:
# Index:    0
# ['2338.doc' '2270.pdf'
#  'twin_collective_magnet_holder_6x6x4mm_twin_collective07.SLDPRT'
#  'EmniyetValfi_1.SLDASM' 'wavelet.pptx' 'Basic Concepts in Sociology.pptx'
#  'GM132M4_1.SLDASM'
#  'twin_collective_head_i2c_connector_housing_twin_collective15.SLDPRT'
#  'exoplanets.1382366914.csv' '2080.docx']
# ['doc' 'pdf' 'sldprt' 'sldasm' 'pptx' 'pptx' 'sldasm' 'sldprt' 'csv'
#  'docx']
#
#
# Index:   10
# ['EmniyetValfi_2c.SLDPRT' '1994.pdf' 'vecfields_UT2 (1).ppt'
#  'exoplanets.1345642951.csv' '1865.docx' 'exoplanets.1344525839.csv'
#  '2190.doc' '1978.docx'
#  'Augmented CycleGAN - Learning Many-to-Many Mappings from Unpaired Data.pdf'
#  '1987.docx']
# ['sldprt' 'pdf' 'ppt' 'csv' 'docx' 'csv' 'doc' 'docx' 'pdf' 'docx']
#
#
# Index:   20
# ['You Only Look Once - Unified, Real Time Object Detection.pdf' '2196.doc'
#  '35Ford.jpg' '2016.docx' 'images.jpg' 'libadsiisex.a' '2334.pdf'
#  'GM225M4_05.SLDPRT' 'solosvx.jpg' 'AlcanWTmap.jpg']
# ['pdf' 'doc' 'jpg' 'docx' 'jpg' 'a' 'pdf' 'sldprt' 'jpg' 'jpg']
#
#
# Index:   30
# ['EK_Mentese_1b.SLDPRT' '2210.docx' '1924.docx' 'libagentdpv.a'
#  'wallpaper-364725.jpg' 'CramerLancia.jpg' 'libamd.dll.a'
#  'Spider-man V2 - T096.cbr' '10. Pattern features.SLDPRT' '1904.docx']
# ['sldprt' 'docx' 'docx' 'a' 'jpg' 'jpg' 'a' 'cbr' 'sldprt' 'docx']
#
#
# Index:   40
# ['UE4-AnalyticsVisualEditing-Android-Shipping-arm64-es2.a' '2285.pdf'
#  '94scenes.jpg' '2164.docx' '2215.doc' 'exoplanets.1382069534.csv'
#  'DirsekHRakor_1.SLDPRT' 'GM225M2_10.SLDPRT' 'libakscoinst.a' '1824.doc']
# ['a' 'pdf' 'jpg' 'docx' 'doc' 'csv' 'sldprt' 'sldprt' 'a' 'doc']
#
#
# Index:   50
# ['exoplanets.1398458270.csv' 'Team944.JPG' 'T 1580_Page_013.png'
#  '2081.pdf' '2135.docx' 'DirsekHRakor_2.SLDPRT' 'CambHwy04.jpg'
#  'exoplanets.1361929102.csv' 'Блок картер для ЯМЗ-236.SLDPRT'
#  '86MHome2.jpg']
# ['csv' 'jpg' 'png' 'pdf' 'docx' 'sldprt' 'jpg' 'csv' 'sldprt' 'jpg']
#
#
# 50 model Saved.....
#
#
#
# Index:   60
# ['2271.pdf' '1948.docx' 'Audi80.jpg' 'exoplanets.1392146926.csv'
#  '2200.docx' '1900.docx' 'exoplanets.1350938355.csv' '2073.docx'
#  '2348.docx' 'vecfields_UT2.ppt']
# ['pdf' 'docx' 'jpg' 'csv' 'docx' 'docx' 'csv' 'docx' 'docx' 'ppt']
#
#
# Index:   70
# ['LED1.png' 'Fangio.jpg' '98Impreza.jpg' '1957.pdf'
#  'Tutorial SolidWorks - Eduardo Valiente.SLDDRW' '2191.pdf' '2232.docx'
#  'twin_collective_throttle2_frame_p2_twin_collective10.SLDPRT'
#  'lara-croft-156900-(www.wallpino.com)-d2bf9737f10ede0e3ab6-2560-1600.jpg'
#  'EmniyetValfi_1e.SLDPRT']
# ['png' 'jpg' 'jpg' 'pdf' 'slddrw' 'pdf' 'docx' 'sldprt' 'jpg' 'sldprt']
#
#
# Index:   80
# ['2230.pdf' '2260.doc' 'T 1580_Page_070.png' 'Заливная горловина.SLDPRT'
#  'twin_collective_tensioner_twin_collective06.SLDPRT' '2235.docx'
#  '2002.docx' '1887.doc' 'GM280M4_02.SLDPRT' '2204.docx']
# ['pdf' 'doc' 'png' 'sldprt' 'sldprt' 'docx' 'docx' 'doc' 'sldprt' 'docx']
#
#
# Index:   90
# ['T 1580_Page_093.png' 'DSC04436.JPG' 'DSC04411.JPG'
#  'Network-Layer-Logical-Addressing.pptx' 'libamstrmid.a'
#  'GM225M2_02.SLDPRT' 'exoplanets.1363703361.csv'
#  'UE4-AnimationCore-Android-Shipping-armv7-es2.a' '2060.docx'
#  'GM225M4_02.SLDPRT']
# ['png' 'jpg' 'jpg' 'pptx' 'a' 'sldprt' 'csv' 'a' 'docx' 'sldprt']
#
#
# Index:  100
# ['Efficient Estimation of Word Representations in Vector Space.pdf'
#  '1919.doc' 'exoplanets.1359126986.csv' 'exoplanets.1376627852.csv'
#  'T 1580_Page_105.png' 'Evolution of Parallel Architectures (1).ppt'
#  'GM225M4_04.SLDPRT' 'exoplanets.1344538166.csv' 'libaelupsvc.a'
#  'demande_autorisation_liste_pieces_modele.docx']
# ['pdf' 'doc' 'csv' 'csv' 'png' 'ppt' 'sldprt' 'csv' 'a' 'docx']
#
#
# 100 model Saved.....
#
#
#
# Index:  110
# ['GM132M4_02.SLDPRT' '1975.docx' 'STRINGS IN JAVA.pptx'
#  'T 1580_Page_022.png' 'GM280S4_10.SLDPRT' 'DSC04424.JPG' 'libadmwprox.a'
#  'Capture.PNG' '1905.docx' 'exoplanets.1363379037.csv']
# ['sldprt' 'docx' 'pptx' 'png' 'sldprt' 'jpg' 'a' 'png' 'docx' 'csv']
#
#
# Index:  120
# ['2294.pdf' 'exoplanets.1343683435.csv' 'Spider-man V2 - T135.cbr'
#  'Module5_ParallelProgramming2.pptx' 'pmech85.jpg' 'libappmgmts.a'
#  '2056.docx' 'exoplanets.1349533321.csv' 'Congestion ctrl  Qos_New.ppt'
#  'Culture new.pptx']
# ['pdf' 'csv' 'cbr' 'pptx' 'jpg' 'a' 'docx' 'csv' 'ppt' 'pptx']
#
#
# Index:  130
# ['exoplanets.1363128206.csv' '1802.pdf' 'T 1580_Page_015.png'
#  'libadptif.a' 'Spider-man V2 - T065.cbr' '2280.docx' '1800.doc'
#  '2177.doc' 'EmniyetValfi_2.SLDASM'
#  'twin_collective_throttle2_grip_twin_collective11.SLDPRT']
# ['csv' 'pdf' 'png' 'a' 'cbr' 'docx' 'doc' 'doc' 'sldasm' 'sldprt']
#
#
# Index:  140
# ['Spider-man V2 - T073.cbr' 'EmniyetValfi_2b.SLDPRT' 'audi.jpg'
#  'Evolution of Parallel Architectures.ppt' '2179.docx'
#  'Spider-man V2 - T022.cbr' '2208.doc' 'T 1580_Page_011.png'
#  'T 1580_Page_041.png' 'T 1580_Page_086.png']
# ['cbr' 'sldprt' 'jpg' 'ppt' 'docx' 'cbr' 'doc' 'png' 'png' 'png']
#
#
# Index:  150
# ['RodS_1984.jpg' '1949.docx'
#  '2018 DensePose -Dense Human Pose Estimation In The Wild.pdf'
#  'exoplanets.1382543804.csv' '2117.docx'
#  'chemistry-desktop-wallpaper-49706-51385-hd-wallpapers.jpg' '2061.docx'
#  'IP Forward_Delivery.ppt' 'DSC04410.JPG' '2025.docx']
# ['jpg' 'docx' 'pdf' 'csv' 'docx' 'jpg' 'docx' 'ppt' 'jpg' 'docx']
#
#
# 150 model Saved.....
#
#
#
# Index:  160
# ['UE4-AnimationCore-Android-Shipping-arm64-es2.a' 'T 1580_Page_088.png'
#  'Коллектор впускной ЯМЗ-236.SLDPRT' 'Alcan5Ls.jpg'
#  'Spider-man V2 - T138.cbr' '2024.docx' '1933.pdf'
#  'UE4-Analytics-Android-Shipping-arm64-es2.a' 'GM280S4_06.SLDPRT'
#  '2189.pdf']
# ['a' 'png' 'sldprt' 'jpg' 'cbr' 'docx' 'pdf' 'a' 'sldprt' 'pdf']
#
#
# Index:  170
# ['OlyLogo.jpg' '2182.pdf'
#  'Learning Phrase Representations using RNN Encoder–Decoder.pdf'
#  'Fan_1a.SLDPRT' '2193.docx' 'T 1580_Page_054.png' 'RDale.jpg' '1995.doc'
#  'Spider-man V2 - T094.cbr' 'InfoAbusePrevent.pptx']
# ['jpg' 'pdf' 'pdf' 'sldprt' 'docx' 'png' 'jpg' 'doc' 'cbr' 'pptx']
#
#
# Index:  180
# ['Henderson_Pogue.jpg' '1839.docx' '2186.docx'
#  '2018-Generating and designing DNA with deep generative.pdf'
#  'exoplanets.1366319053.csv' '2197.pdf' '2053.docx' '2249.pdf'
#  'twin_collective_throttle1_frame_p1_twin_collective12.SLDPRT'
#  'Spider-man V2 - T079.cbr']
# ['jpg' 'docx' 'docx' 'pdf' 'csv' 'pdf' 'docx' 'pdf' 'sldprt' 'cbr']
#
#
# Index:  190
# ['EmniyetValfi_1d.SLDPRT' 'Spider-man V2 - T081.cbr'
#  'Spider-man V2 - T054.cbr' 'T 1580_Page_079.png' '1821.docx'
#  'Objects.pptx' 'exoplanets.1357390299.csv' 'TutorEMVB.SLDASM'
#  'Optical Fibre 2.png' '2160.pdf']
# ['sldprt' 'cbr' 'cbr' 'png' 'docx' 'pptx' 'csv' 'sldasm' 'png' 'pdf']
#
#
# Index:  200
# ['2109.doc' 'T 1580_Page_036.png' 'T 1580_Page_090.png'
#  'T 1580_Page_068.png' 'exoplanets.1374003381.csv'
#  'UE4-AnimationCore-arm64-es2.a' 'exoplanets.1363727744.csv' '2075.docx'
#  '2203.docx' 'libarpack.dll.a']
# ['doc' 'png' 'png' 'png' 'csv' 'a' 'csv' 'docx' 'docx' 'a']
#
#
# 200 model Saved.....
#
#
#
# Index:  210
# ['1935.doc' '2137.pdf' '2308.pdf'
#  'Korshunova_Fast_Face-Swap_Using_ICCV_2017_paper.pdf'
#  'DATE & TIME METHODS IN JAVA.pptx' 'Spider-man V2 - T082.cbr' '2346.pdf'
#  'FJ40Pic.jpg' 'T 1580_Page_072.png' 'exoplanets.1377530015.csv']
# ['doc' 'pdf' 'pdf' 'pdf' 'pptx' 'cbr' 'pdf' 'jpg' 'png' 'csv']
#
#
# Index:  220
# ['Spider-man V2 - T039.cbr' 'UE4-Advertising-Android-Shipping-arm64-es2.a'
#  'alu_square_pipe_10x10x130.SLDPRT' 'T 1580_Page_098.png'
#  '2014-DeepFace-Closing the Gap to Human-Level Performance in Face Verification.pdf'
#  'DSC04444.JPG' 'T 1580_Page_016.png' 'T 1580_Page_104.png'
#  '1811.05233.pdf' 'Module2_HPCParadigms.pptx']
# ['cbr' 'a' 'sldprt' 'png' 'pdf' 'jpg' 'png' 'png' 'pdf' 'pptx']
#
#
# Index:  230
# ['UE4-AndroidAudio-armv7-es2.a' 'TR4.jpg' 'libagentmpx.a' '1804.doc'
#  '2064.doc' '2305.doc' 'Spider-man V2 - T080.cbr' '2163.docx'
#  'ay100938346epa03527263-real.jpg' 'PaulHyder.jpg']
# ['a' 'jpg' 'a' 'doc' 'doc' 'doc' 'cbr' 'docx' 'jpg' 'jpg']
#
#
# Index:  240
# ['T 1580_Page_032.png' 'Ned2006.jpg' 'T 1580_Page_064.png' '1872.doc'
#  '1958.docx' '2276.pdf' 'T 1580_Page_075.png' 'GM225S4_11.SLDPRT'
#  'Disi_T_1.SLDPRT'
#  'КЛ 353.00.00.000 СБ - Конвейер ленточный наклонный 3274В   Нестле Россия нории.JPG']
# ['png' 'jpg' 'png' 'doc' 'docx' 'pdf' 'png' 'sldprt' 'sldprt' 'jpg']
#
#
# Index:  250
# ['Generative Adversarial Networks recover features in astrophysical images of galaxies beyond the deconvolution limit.pdf'
#  '2254.docx' 'rtrack96.jpg' 'Spider-man V2 - T006.cbr' '2147.doc'
#  'exoplanets.1343682749.csv' 'BorycaTorino.jpg' 'Spider-man V2 - T030.cbr'
#  'UE4-AndroidAudio-Android-Shipping-arm64-es2.a' '2340.pdf']
# ['pdf' 'docx' 'jpg' 'cbr' 'doc' 'csv' 'jpg' 'cbr' 'a' 'pdf']
#
#
# 250 model Saved.....
#
#
#
# Index:  260
# ['Module7_HPCBenchmarks.pptx' 'exoplanets.1373302803.csv' 'lib6to4svc.a'
#  '1799.doc' 'UE4-AITestSuite-arm64-es2.a' 'MarvinC.jpg' '2257.docx'
#  '1847.doc' '2205.docx' '1873.doc']
# ['pptx' 'csv' 'a' 'doc' 'a' 'jpg' 'docx' 'doc' 'docx' 'doc']
#
#
# Index:  270
# ['UE4-AnalyticsVisualEditing-arm64-es2.a' 'T 1580_Page_081.png'
#  '1814.docx' '2219.docx' '1986.doc' 'T 1580_Page_074.png' '2105.doc'
#  '2153.doc' 'WinterCaps.jpg'
#  '2018 Audio Adversarial Examples- Targeted attack on text to speech.pdf']
# ['a' 'png' 'docx' 'docx' 'doc' 'png' 'doc' 'doc' 'jpg' 'pdf']
#
#
# Index:  280
# ['Spider-man V2 - T040.cbr' '1942.pdf' '2165.docx' '1837.docx' '2063.doc'
#  'UE4-AITestSuite-armv7-es2.a' 'Spider-man V2 - T032.cbr' '1927.pdf'
#  '2231.doc' '2201.docx']
# ['cbr' 'pdf' 'docx' 'docx' 'doc' 'a' 'cbr' 'pdf' 'doc' 'docx']
#
#
# Index:  290
# ['608_bearing_v1.SLDPRT' 'Spider-man V2 - T009.cbr' 'Systemmodels.ppt'
#  '2065.docx' 'GM132M4_05.SLDPRT' '1986- Backpropagation.pdf'
#  'rottr-sand-png.png' '1853.pdf' '2228.docx' '04AlcanW.gif']
# ['sldprt' 'cbr' 'ppt' 'docx' 'sldprt' 'pdf' 'png' 'pdf' 'docx' 'gif']
#
#
# Index:  300
# ['LED 2.png' '2052.doc' 'BarkeUR2016.jpg' 'T 1580_Page_014.png'
#  'T 1580_Page_089.png' 'exoplanets.1375747096.csv'
#  'Spider-man V2 - T084.cbr' 'for_honor_warriors-wallpaper-2560x1440.jpg'
#  '2151.doc' 'T 1580_Page_101.png']
# ['png' 'doc' 'jpg' 'png' 'png' 'csv' 'cbr' 'jpg' 'doc' 'png']
#
#
# 300 model Saved.....
#
#
#
# Index:  310
# ['DanC2004.jpg'
#  'Linguistic Regularities in Continoues Space Word embeddings.pdf'
#  '2247.pdf' 'Spider-man V2 - T111.cbr' 'FMCoach00.jpg' '2187.pdf'
#  '1983.doc' '2027.docx' 'T 1580_Page_085.png' 'exoplanets.1377742478.csv']
# ['jpg' 'pdf' 'pdf' 'cbr' 'jpg' 'pdf' 'doc' 'docx' 'png' 'csv']
#
#
# Index:  320
# ['Show and Tell - A Neural Image Caption Generator.pdf' '1808.07371.pdf'
#  'T 1580_Page_012.png'
#  'Amazing-Green-Plant-Macro-Wallpaper-Background.jpg'
#  '2015 Adam Optimization.pdf' 'exoplanets.1345745241.csv'
#  'Image Segmentation Edge Quality.pptx' '1831.doc'
#  'Bayes Classifier (1).ppt' 'Bayes Classifier.ppt']
# ['pdf' 'pdf' 'png' 'jpg' 'pdf' 'csv' 'pptx' 'doc' 'ppt' 'ppt']
#
#
# Index:  330
# ['EK_Mentese_1c.SLDPRT' 'sexy_girl_14-wallpaper-2048x1152.jpg' '2333.pdf'
#  '2166.doc' '2114.pdf' 'UE4-AndroidAudio-Android-Shipping-armv7-es2.a'
#  '1984.doc' 'T 1580_Page_049.png' 'libaclui.a' 'WebbAshes.jpg']
# ['sldprt' 'jpg' 'pdf' 'doc' 'pdf' 'a' 'doc' 'png' 'a' 'jpg']
#
#
# Index:  340
# ['2233.docx' 'Spider-man V2 - T139.cbr' 'exoplanets.1372794605.csv'
#  'UE4-AnimationCore-armv7-es2.a' 'T 1580_Page_002.png' 'whsolo94.jpg'
#  'Кожух маховика для ЯМЗ-7511.SLDPRT' 'exoplanets.1379292468.csv'
#  'exoplanets.1436199678.csv' 'libapcups.a']
# ['docx' 'cbr' 'csv' 'a' 'png' 'jpg' 'sldprt' 'csv' 'csv' 'a']
#
#
# Index:  350
# ['libacledit.a' '2072.pdf' '1506.05011.pdf' '2287.pdf'
#  'lara-croft-tomb-raider-159083-(www.wallpino.com)-3bb3a225b4dfe7b9a882-2560-1600.jpg'
#  '2329.docx' '1907.docx' '2043.pdf' 'DSC04407.JPG' '3VE5.SLDPRT']
# ['a' 'pdf' 'pdf' 'pdf' 'jpg' 'docx' 'docx' 'pdf' 'jpg' 'sldprt']
#
#
# 350 model Saved.....
#
#
#
# Index:  360
# ['2113.pdf' 'libapphelp.a' 'pca_2.pptx' 'Module 8 security mechanisms.ppt'
#  'Spider-man V2 - T052.cbr' 'T 1580_Page_023.png' '1880.pdf'
#  'T 1580_Page_059.png' '2007.docx' 'T 1580_Page_087.png']
# ['pdf' 'a' 'pptx' 'ppt' 'cbr' 'png' 'pdf' 'png' 'docx' 'png']
#
#
# Index:  370
# ['2148.pdf' 'Image Formats.pptx' '1977.docx' '2123.docx' '2134.doc'
#  '1952.doc' 'T 1580_Page_029.png' '2032.doc' 'T 1580_Page_069.png'
#  '3TF48.SLDPRT']
# ['pdf' 'pptx' 'docx' 'docx' 'doc' 'doc' 'png' 'doc' 'png' 'sldprt']
#
#
# Index:  380
# ['2275.doc' '1970.doc' '1964.docx' '1803.01271.pdf' '1903.docx'
#  '2277.docx' '1888.doc' 'exoplanets.1379094478.csv'
#  'beautiful_smile_2-wallpaper-5120x2880.jpg' 'SoperWRX.jpg']
# ['doc' 'doc' 'docx' 'pdf' 'docx' 'docx' 'doc' 'csv' 'jpg' 'jpg']
#
#
# Index:  390
# ['T 1580_Page_004.png' '1980.docx' '1963.docx' 'DSC04416.JPG'
#  'MPI_CollectiveCommunication.pptx' '1878.docx' '2167.doc'
#  'T 1580_Page_051.png' '2083.docx' 'Dirsek_1.SLDPRT']
# ['png' 'docx' 'docx' 'jpg' 'pptx' 'docx' 'doc' 'png' 'docx' 'sldprt']
#
#
# Index:  400
# ['Spider-man V2 - T027.cbr' 'GM225S4_09.SLDPRT' '2313.docx'
#  'exoplanets.1370289991.csv' 'exoplanets.1370974701.csv'
#  'T 1580_Page_066.png' '2078.pdf' '2145.pdf' 'Naïve Bayes.pptx'
#  'Spider-man V2 - T058.cbr']
# ['cbr' 'sldprt' 'docx' 'csv' 'csv' 'png' 'pdf' 'pdf' 'pptx' 'cbr']
#
#
# 400 model Saved.....
#
#
#
# Index:  410
# ['1825.docx' 'T 1580_Page_067.png'
#  'Deep captionig with multimodel Recurrent Neural Network.pdf'
#  'Spider-man V2 - T013.cbr' 'GM280S4_08.SLDPRT' 'T 1580_Page_083.png'
#  'EmniyetValfi_2d.SLDPRT' 'libagentsr.a' 'ColorTheory (1).pptx'
#  '1934.docx']
# ['docx' 'png' 'pdf' 'cbr' 'sldprt' 'png' 'sldprt' 'a' 'pptx' 'docx']
#
#
# Index:  420
# ['2140.doc' 'GM132M4_09.SLDPRT' 'GM132M4_06.SLDPRT' '2126.doc'
#  'tomb-raider-162616-(www.wallpino.com)-14c52251ae4e1c0ea665-2560-1600.jpg'
#  'exoplanets.1436202478.csv' '1910.docx' '2349.pdf'
#  'exoplanets.1391620546.csv' 'GM225M2_06.SLDPRT']
# ['doc' 'sldprt' 'sldprt' 'doc' 'jpg' 'csv' 'docx' 'pdf' 'csv' 'sldprt']
#
#
# Index:  430
# ['2236.docx' '2351.pdf' '1850.pdf' '1997.doc' '2030.docx' 'solrodeo.jpg'
#  'T 1580_Page_039.png' 'exoplanets.1350568861.csv' '2227.doc'
#  'Tableau with Hortonworks.pptx']
# ['docx' 'pdf' 'pdf' 'doc' 'docx' 'jpg' 'png' 'csv' 'doc' 'pptx']
#
#
# Index:  440
# ['1869.docx' '2265.doc' 'Spider-man V2 - T122.cbr' '1828.docx' '1944.doc'
#  '1798.doc' '2240.docx' '1965.doc'
#  '2015 A Neural Algorithm of Artistic Style.pdf' '2213.doc']
# ['docx' 'doc' 'cbr' 'docx' 'doc' 'doc' 'docx' 'doc' 'pdf' 'doc']
#
#
# Index:  450
# ['exoplanets.1405830453.csv' '1827.pdf' '2008.doc' '1856.docx'
#  'R-Integration with Tableau [Repaired].ppt' '2062.doc'
#  '02 INTRODUCTION TO JAVA AND DATA TYPES.pptx' '2009.docx'
#  'Spider-man V2 - T025.cbr'
#  'tomb-raider-159533-(www.wallpino.com)-0d810d7e135ec274d24e-2560-1600.jpg']
# ['csv' 'pdf' 'doc' 'docx' 'ppt' 'doc' 'pptx' 'docx' 'cbr' 'jpg']
#
#
# 450 model Saved.....
#
#
#
# Index:  460
# ['2045.docx' 'T 1580_Page_103.png' '9. Loft.SLDPRT' 'bitcoin.pdf'
#  'Spider-man V2 - T126.cbr' '2067.doc' '1909.pdf' '2296.pdf'
#  'Spider-man V2 - T089.cbr' '1806.doc']
# ['docx' 'png' 'sldprt' 'pdf' 'cbr' 'doc' 'pdf' 'pdf' 'cbr' 'doc']
#
#
# Index:  470
# ['T 1580_Page_024.png' 'NormOLA.jpg' '2341.doc' 'TTbike.jpg' '2131.pdf'
#  '2112.doc' '2090.docx' '2093.doc' '2091.docx'
#  'UE4-AndroidAdvertising-Android-Shipping-armv7-es2.a']
# ['png' 'jpg' 'doc' 'jpg' 'pdf' 'doc' 'docx' 'doc' 'docx' 'a']
#
#
# Index:  480
# ['2036.docx' 'Spider-man V2 - T086.cbr' 'GM225M4_07.SLDPRT'
#  'exoplanets.1370649131.csv' '2042.pdf' '88Oly_JK.jpg' '2314.pdf'
#  '2216.pdf' '2128.docx' '2332.docx']
# ['docx' 'cbr' 'sldprt' 'csv' 'pdf' 'jpg' 'pdf' 'pdf' 'docx' 'docx']
#
#
# Index:  490
# ['libagentdp2.a' '2251.pdf' 'GM132M4_07.SLDPRT' 'demande_de_conges.docx'
#  '2181.pdf' '1867.doc' '2150.docx'
#  'RESUME SKILLS-TYPES OF RESUME & CUSTOMIZING RESUME.pptx'
#  'zundcover04.jpg' 'GM225M4_10.SLDPRT']
# ['a' 'pdf' 'sldprt' 'docx' 'pdf' 'doc' 'docx' 'pptx' 'jpg' 'sldprt']
#
#
# Index:  500
# ['2202.docx' '1990.docx' 'exoplanets.1370629221.csv' '2092.doc' 'RonS.JPG'
#  'Spider-man V2 - T007.cbr' '2244.pdf' 'GM225S4_01.SLDPRT' '2014.docx'
#  '2214.doc']
# ['docx' 'docx' 'csv' 'doc' 'jpg' 'cbr' 'pdf' 'sldprt' 'docx' 'doc']
#
#
# 500 model Saved.....
#
#
#
# Index:  510
# ['T 1580_Page_095.png' 'Spider-man V2 - T005.cbr' '1940.doc' '1898.pdf'
#  'exoplanets.1405829155.csv'
#  'КЛ 353.00.00.000 СБ - Конвейер ленточный наклонный.SLDASM'
#  'T 1580_Page_056.png' '2221.doc' 'T 1580_Page_094.png' '2130.pdf']
# ['png' 'cbr' 'doc' 'pdf' 'csv' 'sldasm' 'png' 'doc' 'png' 'pdf']
#
#
# Index:  520
# ['T 1580_Page_053.png' 'GM280M4_04.SLDPRT' 'Spider-man V2 - T012.cbr'
#  "05 MCQ'S.pptx" '2020.docx' '1796.doc' '2104.docx' 'libalrsvc.a'
#  'DIRSEKADAPTOR_1.SLDPRT' 'T 1580_Page_045.png']
# ['png' 'sldprt' 'cbr' 'pptx' 'docx' 'doc' 'docx' 'a' 'sldprt' 'png']
#
#
# Index:  530
# ['exoplanets.1352217457.csv' 'GM225S4_10.SLDPRT'
#  '13692568_624608014370282_8506833875719101092_n.jpg'
#  'Spider-man V2 - T091.cbr' 'JoesTent.jpg' '2038.docx'
#  'UE4-AnimGraphRuntime-arm64-es2.a' '11. 3D Sketching.SLDPRT'
#  'Flow_Control_Error_Control.ppt' 'exoplanets.1350571111.csv']
# ['csv' 'sldprt' 'jpg' 'cbr' 'jpg' 'docx' 'a' 'sldprt' 'ppt' 'csv']
#
#
# Index:  540
# ['exoplanets.1386290410.csv' 'Spider-man V2 - T140.cbr' '1881.pdf'
#  '1841.docx' '1951.docx' 'DirsekRakor_3M.SLDASM' 'DSC04419.JPG'
#  'Spider-man V2 - T121.cbr' '1835.docx' 'SueElder.jpg']
# ['csv' 'cbr' 'pdf' 'docx' 'docx' 'sldasm' 'jpg' 'cbr' 'docx' 'jpg']
#
#
# Index:  550
# ['Deep Reinforcment Learning.pdf' 'AndyDodge2016.jpg'
#  'UE4-Analytics-Android-Shipping-armv7-es2.a' 'exoplanets.1366498126.csv'
#  '2180.doc' 'SCanol04.jpg'
#  'Wang_High-Resolution_Image_Synthesis_CVPR_2018_paper.pdf'
#  'T 1580_Page_021.png' 'UE4-AnalyticsET-armv7-es2.a' '64Caliente.jpg']
# ['pdf' 'jpg' 'a' 'csv' 'doc' 'jpg' 'pdf' 'png' 'a' 'jpg']
#
#
# 550 model Saved.....
#
#
#
# Index:  560
# ['T 1580_Page_025.png' '2029.doc' '1864.doc' 'GM160L4_1.SLDPRT'
#  'GM225M2_04.SLDPRT' 'GM225M2_1.SLDASM' 'Spider-man V2 - T044.cbr'
#  '2192.docx' '2273.pdf' 'exoplanets.1433964010.csv']
# ['png' 'doc' 'doc' 'sldprt' 'sldprt' 'sldasm' 'cbr' 'docx' 'pdf' 'csv']
#
#
# Index:  570
# ['exoplanets.1354758293.csv' 'YuliaPaul2016.jpg'
#  'Quiz - Eduardo Valiente.SLDPRT' 'T 1580_Page_008.png'
#  'exoplanets.1405713597.csv' '2300.pdf' '2119.docx' '2155.docx'
#  'WK510Hairpin.jpg' 'exoplanets.1366398141.csv']
# ['csv' 'jpg' 'sldprt' 'png' 'csv' 'pdf' 'docx' 'docx' 'jpg' 'csv']
#
#
# Index:  580
# ['UE4-AndroidAdvertising-Android-Shipping-arm64-es2.a' 'DuhamelGT350.jpg'
#  'DSC04408.JPG' 'Paraalgodesign.ppt' 'GT350H.jpg'
#  '2015 FaceNet-A Unified Embedding for Face Recognition and Clustering.pdf'
#  '1967.doc' 'T 1580_Page_026.png' 'Spider-man V2 - T087.cbr'
#  'Spider-man V2 - T128.cbr']
# ['a' 'jpg' 'jpg' 'ppt' 'jpg' 'pdf' 'doc' 'png' 'cbr' 'cbr']
#
#
# Index:  590
# ['2110.docx' 'UE4-AnalyticsET-Android-Shipping-armv7-es2.a' '2074.pdf'
#  'GM225M4_01.SLDPRT' 'exoplanets.1376628338.csv' '2175.docx'
#  'exoplanets.1384918903.csv' '2326.pdf' 'Spider-man V2 - T002.cbr'
#  '2307.docx']
# ['docx' 'a' 'pdf' 'sldprt' 'csv' 'docx' 'csv' 'pdf' 'cbr' 'docx']
#
#
# Index:  600
# ['2034.doc' 'T 1580_Page_009.png' '1952DeSotoFiredome8.jpg'
#  'T 1580_Page_005.png' 'libaaaamon.a' '1816.docx' '2098.docx'
#  'Spider-man V2 - T090.cbr' 'exoplanets.1350569209.csv' '2028.docx']
# ['doc' 'png' 'jpg' 'png' 'a' 'docx' 'docx' 'cbr' 'csv' 'docx']
#
#
# 600 model Saved.....
#
#
#
# Index:  610
# ['2101.pdf' '7. Fillet Features.SLDPRT' '2289.pdf' 'DSC04415.JPG'
#  'time_series.pptx' 'exoplanets.1417831552.csv' '2344.pdf'
#  'exoplanets.1344537128.csv' 'T 1580_Page_092.png'
#  'Distributed Representations of Words and Phrases and in their compositionality.pdf']
# ['pdf' 'sldprt' 'pdf' 'jpg' 'pptx' 'csv' 'pdf' 'csv' 'png' 'pdf']
#
#
# Index:  620
# ['1992.pdf' 'exoplanets.1365287084.csv' '2026.docx' 'RichH.jpg' 'ch7.ppt'
#  '1901.doc' 'CoachPisa.jpg' '2206.doc' '1845.docx' '1921.docx']
# ['pdf' 'csv' 'docx' 'jpg' 'ppt' 'doc' 'jpg' 'doc' 'docx' 'docx']
#
#
# Index:  630
# ['Коллектор выпускной правый ЯМЗ-236.SLDPRT' 'T 1580_Page_073.png'
#  'T 1580_Page_018.png' 'UE4-AIModule-Android-Shipping-armv7-es2.a'
#  'Spider-man V2 - T041.cbr' 'exoplanets.1377741600.csv'
#  'Impact of Religions 1.pptx' 'GM132M4_03.SLDPRT'
#  'UE4-AnimGraphRuntime-Android-Shipping-arm64-es2.a' 'T 1580_Page_096.png']
# ['sldprt' 'png' 'png' 'a' 'cbr' 'csv' 'pptx' 'sldprt' 'a' 'png']
#
#
# Index:  640
# ['Spider-man V2 - T024.cbr' 'IMG_20161025_235338.jpg' '2248.pdf'
#  'YuliaPaul2016a.jpg' 'GM225M4_08.SLDPRT' '1892.pdf' 'JeffG98.jpg'
#  '2274.doc' 'Spider-man V2 - T115.cbr' 'JohnnyR100.jpg']
# ['cbr' 'jpg' 'pdf' 'jpg' 'sldprt' 'pdf' 'jpg' 'doc' 'cbr' 'jpg']
#
#
# Index:  650
# ['Коллектор выпускной левый ЯМЗ-236.SLDPRT' '2087.pdf'
#  'T 1580_Page_084.png' '1960.doc' 'ECC.pptx' 'T 1580_Page_097.png'
#  '2099.doc' '2159.docx' '1852.doc' 'T 1580_Page_065.png']
# ['sldprt' 'pdf' 'png' 'doc' 'pptx' 'png' 'doc' 'docx' 'doc' 'png']
#
#
# 650 model Saved.....
#
#
#
# Index:  660
# ['1917.pdf' '1902.pdf' 'exoplanets.1369842403.csv' '1805.docx'
#  'GM132M4_01.SLDPRT' '2136.docx' '2261.doc' '2051.doc' '2018.doc'
#  'earth-day.jpeg']
# ['pdf' 'pdf' 'csv' 'docx' 'sldprt' 'docx' 'doc' 'doc' 'doc' 'jpeg']
#
#
# Index:  670
# ['TCP UDP.ppt' 'EmniyetValfi_1c.SLDPRT' '04XT2.jpg'
#  'exoplanets.1392162267.csv' '2144.docx' '3VU1300.SLDPRT'
#  'twin_collective_throttle1_grip_twin_collective14.SLDPRT'
#  'Higgs73Mini.jpg' 'exoplanets.1370369143.csv' 'DSC04420.JPG']
# ['ppt' 'sldprt' 'jpg' 'csv' 'docx' 'sldprt' 'sldprt' 'jpg' 'csv' 'jpg']
#
#
# Index:  680
# ['JeffM.JPG' 'Classless addressing.ppt' 'GM225S4_06.SLDPRT'
#  'TR_SKagwaySm.jpg' 'exoplanets.1349984686.csv' '2264.doc'
#  'Spider-man V2 - T113.cbr' '2229.doc' 'T 1580_Page_106.png' '1891.doc']
# ['jpg' 'ppt' 'sldprt' 'jpg' 'csv' 'doc' 'cbr' 'doc' 'png' 'doc']
#
#
# Index:  690
# ['Landscape Format.slddrt' "10 MCQ'S.pptx" 'Riddell76TR6.jpg'
#  'T 1580_Page_057.png' 'exoplanets.1370968817.csv' 'slide_11.jpg'
#  'GM225S4_08.SLDPRT' 'Головка блокаЯМЗ -236.SLDPRT' 'GM132M4_08.SLDPRT'
#  'T 1580_Page_077.png']
# ['slddrt' 'pptx' 'jpg' 'png' 'csv' 'jpg' 'sldprt' 'sldprt' 'sldprt' 'png']
#
#
# Index:  700
# ['UE4-AnalyticsVisualEditing-armv7-es2.a' 'T 1580_Page_058.png'
#  'JSBigLake.JPG' '1807.11205.pdf' 'Spider-man V2 - T010.cbr'
#  'exoplanets.1366427050.csv' '2176.pdf' '2250.pdf' 'BarkeUR.jpg'
#  '2058.doc']
# ['a' 'png' 'jpg' 'pdf' 'cbr' 'csv' 'pdf' 'pdf' 'jpg' 'doc']
#
#
# 700 model Saved.....
#
#
#
# Index:  710
# ['2125.doc' 'Pete04.jpg' '2263.doc' 'libadsldpc.a' '2129.docx'
#  'Spider-man V2 - T131.cbr' 'exoplanets.1395433410.csv'
#  '1998 Object Recognition with gradient Based Learning.pdf' '2162.docx'
#  'Association Rule Mining.pptx']
# ['doc' 'jpg' 'doc' 'a' 'docx' 'cbr' 'csv' 'pdf' 'docx' 'pptx']
#
#
# Index:  720
# ['GaryArcticCircle2008.jpg' 'Левое колено ТКР.SLDPRT' '2345.pdf'
#  'EmniyetValfi_1g.SLDPRT'
#  'Deep Visual-Semantic Alignments for Generating Image Descriptions.pdf'
#  '2245.pdf' '1859.doc' '1860.doc' 'Spider-man V2 - T014.cbr'
#  'T 1580_Page_060.png']
# ['jpg' 'sldprt' 'pdf' 'sldprt' 'pdf' 'pdf' 'doc' 'doc' 'cbr' 'png']
#
#
# Index:  730
# ['exoplanets.1376928656.csv' 'exoplanets.1373571950.csv' '1815.docx'
#  '1950.pdf' '1918.docx' 'GM160M2_1.SLDASM' 'exoplanets.1374871557.csv'
#  '2237.doc' '1849.doc' 'Gary2008.jpg']
# ['csv' 'csv' 'docx' 'pdf' 'docx' 'sldasm' 'csv' 'doc' 'doc' 'jpg']
#
#
# Index:  740
# ['Spider-man V2 - T088.cbr' 'T 1580_Page_020.png'
#  'Трубка перепускная 236-1306080-А.SLDPRT' 'libagentpsh.a' '2330.pdf'
#  'exoplanets.1370294277.csv' 'libadsnt.a' '2347.pdf'
#  'Color Models and File formats.pptx' 'UE4-AIModule-arm64-es2.a']
# ['cbr' 'png' 'sldprt' 'a' 'pdf' 'csv' 'a' 'pdf' 'pptx' 'a']
#
#
# Index:  750
# ['Spider-man V2 - T008.cbr' '1928.docx' 'Spider-man V2 - T051.cbr'
#  '2304.pdf' 'Presentation 2019.pptx' 'T 1580_Page_040.png'
#  'T 1580_Page_102.png' '1974.doc' 'T 1580_Page_010.png' '1836.docx']
# ['cbr' 'docx' 'cbr' 'pdf' 'pptx' 'png' 'png' 'doc' 'png' 'docx']
#
#
# 750 model Saved.....
#
#
#
# Index:  760
# ['2044.docx' '2059.doc' 'exoplanets.1433966679.csv' 'DSC04439.JPG'
#  'Gardner04.jpg' 'exoplanets.1357432837.csv' '1848.docx' '1830.docx'
#  'UE4-AnimGraphRuntime-armv7-es2.a' '1961.doc']
# ['docx' 'doc' 'csv' 'jpg' 'jpg' 'csv' 'docx' 'docx' 'a' 'doc']
#
#
# Index:  770
# ['T 1580_Page_052.png'
#  'High-Resolution Image Synthesis and Semantic Manipulation with Conditional GANs.pdf'
#  '1938.pdf' '1998.pdf' 'T 1580_Page_099.png' 'T 1580_Page_003.png'
#  'Spider-man V2 - T050.cbr' '2050.docx' '2290.doc'
#  'exoplanets.1403298153.csv']
# ['png' 'pdf' 'pdf' 'pdf' 'png' 'png' 'cbr' 'docx' 'doc' 'csv']
#
#
# Index:  780
# ['EmniyetValfi_1b.SLDPRT' 'Spider-man V2 - T085.cbr'
#  'twin_collective_enclosure_bottom_p2_twin_collective03.SLDPRT'
#  'exoplanets.1405716640.csv' 'TreesAndGraphs (1).pptx'
#  'exoplanets.1357480331.csv' '1819.doc' 'T 1580_Page_027.png'
#  'DSC04417.JPG' 'Spider-man V2 - T095.cbr']
# ['sldprt' 'cbr' 'sldprt' 'csv' 'pptx' 'csv' 'doc' 'png' 'jpg' 'cbr']
#
#
# Index:  790
# ['Труба водянная левая ЯМЗ-236.SLDPRT' 'exoplanets.1407012959.csv'
#  '1885.docx' 'GM225S4_02.SLDPRT'
#  'tomb-raider-179652-(www.wallpino.com)-02ea8e0baa75c954fddc-2560-1600.jpg'
#  '2183.docx' '2336.doc' '2121.docx' '1931.docx' '1818.doc']
# ['sldprt' 'csv' 'docx' 'sldprt' 'jpg' 'docx' 'doc' 'docx' 'docx' 'doc']
#
#
# Index:  800
# ['2149.docx' 'buffalo04.jpg' '2066.docx' '1915.docx' 'GM225M4_03.SLDPRT'
#  'REPRESENTATION DESCRIPTION.pptx' 'exoplanets.1372180879.csv'
#  'exoplanets.1365526972.csv' '1838.docx' 'Fan_1b.SLDPRT']
# ['docx' 'jpg' 'docx' 'docx' 'sldprt' 'pptx' 'csv' 'csv' 'docx' 'sldprt']
#
#
# 800 model Saved.....
#
#
#
# Index:  810
# ['T 1580_Page_034.png' 'Hal2018.jpg' '08 ABSTRACTION.pptx'
#  'GM280S4_04.SLDPRT' 'Spider-man V2 - T001.cbr' '1820.doc'
#  'T 1580_Page_033.png' 'Spider-man V2 - T114.cbr'
#  'Spider-man V2 - T133.cbr' 'SteveSalmon.jpg']
# ['png' 'jpg' 'pptx' 'sldprt' 'cbr' 'doc' 'png' 'cbr' 'cbr' 'jpg']
#
#
# Index:  820
# ['2143.pdf' 'libadrot.a' 'JoeKevin04.JPG' 'T 1580_Page_080.png'
#  'Mike_Jodi.jpg' 'exoplanets.1361201611.csv' '2071.doc'
#  'T 1580_Page_046.png' '2146.pdf' 'Spider-man V2 - T028.cbr']
# ['pdf' 'a' 'jpg' 'png' 'jpg' 'csv' 'doc' 'png' 'pdf' 'cbr']
#
#
# Index:  830
# ['1871.docx' '2198.docx' 'SteveB.JPG' '8. Revolve and Sweep.SLDPRT'
#  'Civata_Somun.SLDPRT' '2337.pdf' 'Spider-man V2 - T098.cbr'
#  'EmniyetValfi_1a.SLDPRT' '2118.pdf' '3UA62.SLDPRT']
# ['docx' 'docx' 'jpg' 'sldprt' 'sldprt' 'pdf' 'cbr' 'sldprt' 'pdf' 'sldprt']
#
#
# Index:  840
# ['2102.docx' 'Ng-MLY01-13.pdf' 'T 1580_Page_031.png' '1899.docx'
#  'T 1580_Page_050.png' 'KathrynH.jpg' '2178.pdf' '1894.pdf'
#  'Routing Protocols.ppt' 'T 1580_Page_047.png']
# ['docx' 'pdf' 'png' 'docx' 'png' 'jpg' 'pdf' 'pdf' 'ppt' 'png']
#
#
# Index:  850
# ['twin_collective_throttle1_frame_p2_twin_collective13.SLDPRT'
#  'T 1580_Page_017.png' '1968.docx' '2310.docx' 'libappmgr.a'
#  'GM225M4_09.SLDPRT' '2122.doc'
#  'AAEAAQAAAAAAAALuAAAAJDRiNzI4NzdmLTg2MzMtNDZkYi1hOWQyLTg5ZDc4ZmRkY2MwMA.gif'
#  '2082.docx' 'UE4-AnalyticsVisualEditing-Android-Shipping-armv7-es2.a']
# ['sldprt' 'png' 'docx' 'docx' 'a' 'sldprt' 'doc' 'gif' 'docx' 'a']
#
#
# 850 model Saved.....
#
#
#
# Index:  860
# ['1857.doc' '2331.pdf' 'twin_collective.SLDASM' 'DirsekRakor_3.SLDPRT'
#  '1883.doc' '2171.docx' 'visual attributes.pptx'
#  'exoplanets.1398459223.csv' '2086.docx' '2076.docx']
# ['doc' 'pdf' 'sldasm' 'sldprt' 'doc' 'docx' 'pptx' 'csv' 'docx' 'docx']
#
#
# Index:  870
# ['2295.pdf' 'T 1580_Page_107.png' 'Spider-man V2 - T134.cbr'
#  'exoplanets.1371835339.csv' '2120.doc' 'E350Valzez.jpg'
#  'Фильтр центробежной очистки масла.SLDPRT' 'Spider-man V2 - T037.cbr'
#  'UE4-AndroidAudio-arm64-es2.a' '07 ENCAPSULATION.pptx']
# ['pdf' 'png' 'cbr' 'csv' 'doc' 'jpg' 'sldprt' 'cbr' 'a' 'pptx']
#
#
# Index:  880
# ['2014 Going deeper with convolutions.pdf' 'exoplanets.1375205968.csv'
#  '2156.pdf' '2041.docx' 'Spider-man V2 - T100.cbr'
#  'exoplanets.1357423542.csv' '1801.docx'
#  'UE4-AndroidAdvertising-armv7-es2.a' '2111.docx' '1813.docx']
# ['pdf' 'csv' 'pdf' 'docx' 'cbr' 'csv' 'docx' 'a' 'docx' 'docx']
#
#
# Index:  890
# ['exoplanets.1364406333.csv' '1736.doc' 'exoplanets.1362946857.csv'
#  '1866.docx' 'download.jpg' 'Yulia2016.jpg' '1855.doc'
#  'Module6_AchievingPerformance.pptx' '1914.docx' 'T 1580_Page_019.png']
# ['csv' 'doc' 'csv' 'docx' 'jpg' 'jpg' 'doc' 'pptx' 'docx' 'png']
#
#
# Index:  900
# ['T 1580_Page_044.png' 'T 1580_Page_108.png' '2019.docx' 'libagtintl.a'
#  'cristiano-ronaldo-wallpapers-hd-24.jpg' '2312.doc' 'libadsmsext.a'
#  'exoplanets.1387215929.csv' 'Kevin04.jpg' '2103.docx']
# ['png' 'png' 'docx' 'a' 'jpg' 'doc' 'a' 'csv' 'jpg' 'docx']
#
#
# 900 model Saved.....
#
#
#
# Index:  910
# ['twin_collective_rubber_bands_holder_twin_collective08.SLDPRT'
#  'T 1580_Page_007.png' 'libaqueue.a' 'exoplanets.1366982842.csv'
#  '2157.pdf' 'exoplanets.1354888944.csv' 'Pin - Eduardo Valiente.SLDPRT'
#  '1896.docx' '1937.doc' '2152.doc']
# ['sldprt' 'png' 'a' 'csv' 'pdf' 'csv' 'sldprt' 'docx' 'doc' 'doc']
#
#
# Index:  920
# ['1875.docx' 'exoplanets.1363982294.csv' 'exoplanets.1351655340.csv'
#  '2220.doc' '1807.doc' '2238.docx' 'Spider-man V2 - T118.cbr'
#  'DB1150GS.JPG' 'Труба водянная правая ЯМЗ-236.SLDPRT' '2116.docx']
# ['docx' 'csv' 'csv' 'doc' 'doc' 'docx' 'cbr' 'jpg' 'sldprt' 'docx']
#
#
# Index:  930
# ['Spider-man V2 - T110.cbr' 'GM280S4_09.SLDPRT' '2325.doc'
#  'tomb-raider-181824-(www.wallpino.com)-d49e09ea887cb388cb64-2560-1600.jpg'
#  'GM132M4_04.SLDPRT' 'exoplanets.1357392743.csv' '1826.docx' '2001.pdf'
#  'MessageAuthentication.ppt' '2124.pdf']
# ['cbr' 'sldprt' 'doc' 'jpg' 'sldprt' 'csv' 'docx' 'pdf' 'ppt' 'pdf']
#
#
# Index:  940
# ['twin_collective_lever_connector_twin_collective05.SLDPRT'
#  '06 OBJECTS.pptx' '2010.doc' '1926.doc'
#  'formulaire_demande_d_agrement_ets_.docx' '2328.pdf'
#  'Deep Neuroevolution - Genetic Algorithms are a Competitive Alternative for Training Deep Neural Networks for Reinforcment Learning.pdf'
#  '1981.doc' 'libadvpack.a' 'Tutor.SLDASM']
# ['sldprt' 'pptx' 'doc' 'doc' 'docx' 'pdf' 'pdf' 'doc' 'a' 'sldasm']
#
#
# Index:  950
# ['15. Animation or Motion Tutorial.SLDASM' '2106.pdf' '1989.docx'
#  '2185.doc' 'libadmparse.a' '1890.doc'
#  '2015 Deep Residual Learning for Image Recognition.pdf'
#  'exoplanets.1373302635.csv' 'GM132M4_10.SLDPRT'
#  'exoplanets.1373311707.csv']
# ['sldasm' 'pdf' 'docx' 'doc' 'a' 'doc' 'pdf' 'csv' 'sldprt' 'csv']
#
#
# 950 model Saved.....
#
#
#
# Index:  960
# ['EmniyetValfi_2a.SLDPRT' '1897.doc' 'Spider-man V2 - T097.cbr'
#  'GM225M2_03.SLDPRT' 'DSC04414.JPG' '2003.doc' 'UE4-Analytics-arm64-es2.a'
#  '2309.doc' '2226.docx' '1870.docx']
# ['sldprt' 'doc' 'cbr' 'sldprt' 'jpg' 'doc' 'a' 'doc' 'docx' 'docx']
#
#
# Index:  970
# ['1863.docx'
#  'КЛ 353.00.00.000 СБ - Конвейер ленточный наклонный02 3274В   Нестле Россия нории.JPG'
#  'exoplanets.1375734101.csv' 'exoplanets.1351656695.csv'
#  'GM225M4_06.SLDPRT' 'exoplanets.1370648422.csv'
#  'Module4_Message Passing Interface.pptx' '2035.docx'
#  'T 1580_Page_048.png'
#  'twin_collective_enclosure_bottom_p1_twin_collective02.SLDPRT']
# ['docx' 'jpg' 'csv' 'csv' 'sldprt' 'csv' 'pptx' 'docx' 'png' 'sldprt']
#
#
# Index:  980
# ['2168.doc' 'GM280S4_05.SLDPRT' '2037.doc' 'Sociology 1.pptx'
#  'exoplanets.1417828941.csv' 'T 1580_Page_109.png'
#  'exoplanets.1363121253.csv' 'Spider-man V2 - T127.cbr' '2335.pdf'
#  '2017.docx']
# ['doc' 'sldprt' 'doc' 'pptx' 'csv' 'png' 'csv' 'cbr' 'pdf' 'docx']
#
#
# Index:  990
# ['Globe.jpg' 'Holdaway69Mini.jpg' 'Ancient Edn.pptx' '1874.docx'
#  '14. Assembly Mates Tutorial.SLDASM' '2352.pdf' '1913.doc'
#  'Spider-man V2 - T029.cbr' 'Spider-man V2 - T015.cbr'
#  'Spider-man V2 - T125.cbr']
# ['jpg' 'jpg' 'pptx' 'docx' 'sldasm' 'pdf' 'doc' 'cbr' 'cbr' 'cbr']
#
#
# Index: 1000
# ['DIYOT.SLDPRT' 'Spider-man V2 - T123.cbr' '2194.docx'
#  'exoplanets.1398458662.csv' 'cppmap-2012.png' '1810.pdf' '2225.docx'
#  'UE4-Advertising-arm64-es2.a' 'EmniyetValfi_3a.SLDPRT' '1817.pdf']
# ['sldprt' 'cbr' 'docx' 'csv' 'png' 'pdf' 'docx' 'a' 'sldprt' 'pdf']
#
#
# 1000 model Saved.....
#
#
#
# Index: 1010
# ['Топливный насос высокого давления.SLDPRT' '1811.doc'
#  'Indian Heritage and Culture 1.pptx' 'exoplanets.1339306132.csv'
#  '1939.doc' '2217.docx' 'Bradmetzger.jpg' '1955.pdf'
#  'Spider-man V2 - T093.cbr' '2100.doc']
# ['sldprt' 'doc' 'pptx' 'csv' 'doc' 'docx' 'jpg' 'pdf' 'cbr' 'doc']
#
#
# Index: 1020
# ['Fan_1.SLDASM' '2262.doc' '2342.pdf' '1941.doc' '2212.docx' '1972.pdf'
#  'T 1580_Page_063.png' 'exoplanets.1405828541.csv' 'libamstream.a'
#  'Воздушный фильтр.SLDPRT']
# ['sldasm' 'doc' 'pdf' 'doc' 'docx' 'pdf' 'png' 'csv' 'a' 'sldprt']
#
#
# Index: 1030
# ['2350.docx' 'libactiveds.a' 'Spider-man V2 - T083.cbr'
#  'GM225M2_05.SLDPRT'
#  '2015 Very Deep Convulation Networks For Large Scale Image Recognization.pdf'
#  'Spider-man V2 - T011.cbr' '2015.docx' 'T 1580_Page_037.png' '2222.pdf'
#  'Optical fibre1.png']
# ['docx' 'a' 'cbr' 'sldprt' 'pdf' 'cbr' 'docx' 'png' 'pdf' 'png']
#
#
# Index: 1040
# ['exoplanets.1365719775.csv' '2223.pdf' '1858.doc' 'GM280S4_07.SLDPRT'
#  'libadsldp.a' 'Tutor2.SLDPRT'
#  'BussetiOsbandWong-DeepLearningForTimeSeriesModeling.pdf'
#  'Лопась ТМЗ.SLDPRT' 'Spider-man V2 - T129.cbr' 'AlcanWinterLogo.jpg']
# ['csv' 'pdf' 'doc' 'sldprt' 'a' 'sldprt' 'pdf' 'sldprt' 'cbr' 'jpg']
#
#
# Index: 1050
# ['UE4-Analytics-armv7-es2.a' 'NinjaPeter.jpg' 'Set Theory 1.pptx'
#  'Single Core and Multi core Processor.pptx' 'GM225M2_08.SLDPRT'
#  'T 1580_Page_006.png' 'EmniyetValfi_1i.SLDPRT' '2195.docx' '1999.pdf'
#  '1979.docx']
# ['a' 'jpg' 'pptx' 'pptx' 'sldprt' 'png' 'sldprt' 'docx' 'pdf' 'docx']
#
#
# 1050 model Saved.....
#
#
#
# Index: 1060
# ['GM280S4_1.SLDASM' '2252.docx' '1843.pdf' '2133.docx'
#  'Spider-man V2 - T124.cbr' '2089.docx' '2327.pdf' '1929.pdf' '2097.docx'
#  'exoplanets.1368725411.csv']
# ['sldasm' 'docx' 'pdf' 'docx' 'cbr' 'docx' 'pdf' 'pdf' 'docx' 'csv']
#
#
# Index: 1070
# ['Spider-man V2 - T034.cbr' 'Фильтр грубой очистки масла.SLDPRT'
#  '1840.doc' 'Spider-man V2 - T016.cbr' 'GM280S4_03.SLDPRT'
#  'exoplanets.1370466505.csv' '2127.doc' '1868.docx' 'SMOTE.pptx'
#  'GM280M4_1.SLDASM']
# ['cbr' 'sldprt' 'doc' 'cbr' 'sldprt' 'csv' 'doc' 'docx' 'pptx' 'sldasm']
#
#
# Index: 1080
# ['2241.pdf' 'UE4-AnalyticsET-arm64-es2.a' '1993.docx' '2055.docx'
#  '2284.pdf' '1808.docx' '2069.pdf' 'exoplanets.1350306799.csv' '2234.pdf'
#  '2158.doc']
# ['pdf' 'a' 'docx' 'docx' 'pdf' 'docx' 'pdf' 'csv' 'pdf' 'doc']
#
#
# Index: 1090
# ['2209.docx' '2255.docx' '2085.docx' 'libagentanm.a' '2272.docx'
#  '1947.docx' '1854.doc' '2012- Large Scale Distributed Deep Networks.pdf'
#  '1988.doc' 'exoplanets.1366318715.csv']
# ['docx' 'docx' 'docx' 'a' 'docx' 'docx' 'doc' 'pdf' 'doc' 'csv']
#
#
# Index: 1100
# ['T 1580_Page_091.png' 'ImprezaTW.jpg' '1953.pdf' '1842.docx'
#  'GM225M2_07.SLDPRT' 'secret.jpg' 'GM280S4_01.SLDPRT' '1861.doc'
#  'exoplanets.1363635052.csv' 'GM225M2_09.SLDPRT']
# ['png' 'jpg' 'pdf' 'docx' 'sldprt' 'jpg' 'sldprt' 'doc' 'csv' 'sldprt']
#
#
# 1100 model Saved.....
#
#
#
# Index: 1110
# ['CortinaTbird.jpg' 'GM280S4_11.SLDPRT' 'exoplanets.1357413698.csv'
#  '2013.docx' 'AngiezRide.jpg' 'T 1580_Page_071.png' 'T 1580_Page_076.png'
#  '2199.docx' 'Поддон двигателя 236.SLDPRT'
#  'lara-croft-fighting-a-bear-rise-of-the-tomb-raider-wallpaper-5014.jpg']
# ['jpg' 'sldprt' 'csv' 'docx' 'jpg' 'png' 'png' 'docx' 'sldprt' 'jpg']
#
#
# Index: 1120
# ['TRActionNov2015.jpg' 'UE4-AIModule-Android-Shipping-arm64-es2.a'
#  'GM225M2_01.SLDPRT' '1956.doc' 'exoplanets.1369077813.csv'
#  'GM225S4_04.SLDPRT' 'exoplanets.1405705041.csv' '2138.doc'
#  'Spider-man V2 - T112.cbr' 'exoplanets.1389470746.csv']
# ['jpg' 'a' 'sldprt' 'doc' 'csv' 'sldprt' 'csv' 'doc' 'cbr' 'csv']
#
#
# Index: 1130
# ['1893.pdf' 'EmniyetValfi_1f.SLDPRT' '2224.pdf' '2047.docx'
#  'exoplanets.1357481394.csv' 'exoplanets.1357141378.csv' '1943.doc'
#  'twin_collective_enclosure_twin_collective01.SLDPRT' '2077.doc'
#  '1823.docx']
# ['pdf' 'sldprt' 'pdf' 'docx' 'csv' 'csv' 'doc' 'sldprt' 'doc' 'docx']
#
#
# Index: 1140
# ['1889.docx' 'exoplanets.1365096209.csv' '1810.12894.pdf'
#  'ColorTheory.pptx' '11 ARRAYS.pptx' '2154.doc' '1969.pdf' 'ship.jpg'
#  '1834.doc' 'T 1580_Page_001.png']
# ['docx' 'csv' 'pdf' 'pptx' 'pptx' 'doc' 'pdf' 'jpg' 'doc' 'png']
#
#
# Index: 1150
# ['exoplanets.1366987585.csv' 'dawson.jpg' '2022.docx' '1930.doc'
#  '1906.docx' 'Cameron_Gary2010.JPG' '2259.doc' 'exoplanets.1363106899.csv'
#  'c++17 cppmap3.0 (screen 8bit 96dpi).png' '2343.pdf']
# ['csv' 'jpg' 'docx' 'doc' 'docx' 'jpg' 'doc' 'csv' 'png' 'pdf']
#
#
# 1150 model Saved.....
#
#
#
# Index: 1160
# ['ch12.ppt' 'pcom96.jpg' '2048.docx' '1833.doc' 'Module 4.pptx' '1925.doc'
#  '8OUT_300501.SLDASM' 'DE2bGfs.jpg' 'GM225M4_11.SLDPRT' '2084.docx']
# ['ppt' 'jpg' 'docx' 'doc' 'pptx' 'doc' 'sldasm' 'jpg' 'sldprt' 'docx']
#
#
# Index: 1170
# ['1982.docx'
#  '2012 Imagenet-Classification-with-Deep-Convolutional-Neural-Networks.pdf'
#  'T 1580_Page_043.png' '1877.pdf' "12 MCQ'S.pptx" '2211.doc' '1946.pdf'
#  'exoplanets.1361901837.csv' '1882.doc' 'exoplanets.1363283014.csv']
# ['docx' 'pdf' 'png' 'pdf' 'pptx' 'doc' 'pdf' 'csv' 'doc' 'csv']
#
#
# Index: 1180
# ['1945.pdf' '1832.doc' '01 Orintation.pptx' '2188.pdf'
#  'exoplanets.1364850955.csv' '2049.docx' 'Log2.pptx'
#  '03 VARIABLES AND MCQS.pptx' '2169.docx' '2207.docx']
# ['pdf' 'doc' 'pptx' 'pdf' 'csv' 'docx' 'pptx' 'pptx' 'docx' 'docx']
#
#
# Index: 1190
# ['tomb-raider-162740-(www.wallpino.com)-6557a5da161ca89b99a9-2560-1600.jpg'
#  'rise-of-the-tomb-raider-wallpaper-wallpaper-3.jpg' 'T 1580_Page_055.png'
#  'T 1580_Page_082.png' 'IceHotel04.jpg' '2012.docx'
#  'Двигатель ЯМЗ-236 в сборе.SLDASM' 'exoplanets.1405826991.csv' '1936.doc'
#  '2297.docx']
# ['jpg' 'jpg' 'png' 'png' 'jpg' 'docx' 'sldasm' 'csv' 'doc' 'docx']
#
#
# Index: 1200
# ['SteveP.jpg' '2281.docx' 'Bombe_1.SLDPRT' 'WebbMemorial.jpg' '1959.docx'
#  'GM225M2_11.SLDPRT'
#  'twin_collective_throttle2_frame_p1_twin_collective09.SLDPRT' '2115.docx'
#  '2174.docx' '1795.pdf']
# ['jpg' 'docx' 'sldprt' 'jpg' 'docx' 'sldprt' 'sldprt' 'docx' 'docx' 'pdf']
#
#
# 1200 model Saved.....
#
#
#
# Index: 1210
# ['1954.pdf' 'Вентилятор в сборе ТМЗ.SLDASM' 'T 1580_Page_035.png'
#  'Boru_1.SLDPRT' 'exoplanets.1370887651.csv' '04 PRINTING.pptx'
#  'GM225S4_05.SLDPRT' '2012Jacket.jpg' 'exoplanets.1417830089.csv'
#  'T 1580_Page_030.png']
# ['pdf' 'sldasm' 'png' 'sldprt' 'csv' 'pptx' 'sldprt' 'jpg' 'csv' 'png']
#
#
# Index: 1220
# ['exoplanets.1346702818.csv' '09 CONTROL STRUCTURES.pptx'
#  'Патрубок соединительный.SLDPRT' '2070.docx' '2298.docx' '1908.docx'
#  'Spider-man V2 - T043.cbr' 'T 1580_Page_028.png' 'SaabMidnightDome.jpg'
#  'UE4-AndroidAdvertising-arm64-es2.a']
# ['csv' 'pptx' 'sldprt' 'docx' 'docx' 'docx' 'cbr' 'png' 'jpg' 'a']
#
#
# Index: 1230
# ['exoplanets.1346100560.csv' '1612.05048.pdf' '1916.pdf'
#  'GM225S4_03.SLDPRT' 'UE4-Advertising-armv7-es2.a'
#  'alu_square_pipe_10x10x50.SLDPRT' 'cr7-free-kick-wallpapers-android.jpg'
#  '2014- Generative Adversarial Nets.pdf' 'DIRENC.SLDPRT' '1911.docx']
# ['csv' 'pdf' 'pdf' 'sldprt' 'a' 'sldprt' 'jpg' 'pdf' 'sldprt' 'docx']
#
#
# Index: 1240
# ['exoplanets.1353331489.csv' '2161.pdf' 'exoplanets.1340916034.csv'
#  'moscow_city_2017_art_irbis_production-wallpaper-3554x1999.jpg'
#  'CSE4003 Cyber Security.ppt' 'Spider-man V2 - T021.cbr'
#  'Spider-man V2 - T119.cbr' 'EmniyetValfi_1i0.SLDPRT'
#  'Spider-man V2 - T116.cbr' 'libagentctl.a']
# ['csv' 'pdf' 'csv' 'jpg' 'ppt' 'cbr' 'cbr' 'sldprt' 'cbr' 'a']
#
#
# Index: 1250
# ['CUDA Programming-FewMoreExamples-1.pptx' 'exoplanets.1366947155.csv'
#  '2068.docx' 'margaret.jpg' '2239.pdf' '2021.docx' '2279.pdf'
#  'libadvapi32.a' '2132.doc' '2173.pdf']
# ['pptx' 'csv' 'docx' 'jpg' 'pdf' 'docx' 'pdf' 'a' 'doc' 'pdf']
#
#
# 1250 model Saved.....
#
#
#
# Index: 1260
# ['TreesAndGraphs.pptx' 'exoplanets.1340519518.csv' 'DSC04413.JPG'
#  '2006.doc' 'visual attributes (1).pptx' '2108.doc' '2057.docx'
#  '2046.docx' 'Image Compression Complete.pptx'
#  'UE4-Advertising-Android-Shipping-armv7-es2.a']
# ['pptx' 'csv' 'jpg' 'doc' 'pptx' 'doc' 'docx' 'docx' 'pptx' 'a']
#
#
# Index: 1270
# ['1844.pdf' 'Стартер для 7511.SLDPRT' '2266.docx' '2023.doc' '1879.pdf'
#  'libaqadmin.a' '1862.doc' 'exoplanets.1385074656.csv' '1895.doc'
#  '2218.pdf']
# ['pdf' 'sldprt' 'docx' 'doc' 'pdf' 'a' 'doc' 'csv' 'doc' 'pdf']
#
#
# Index: 1280
# ['DSC04440.JPG' '2246.docx' '13 MCQS ON STRINGS.pptx'
#  'exoplanets.1405717225.csv'
#  'sergio_ramos_wallpaper_by_backflip_imagination_by_backflipimagination-d77d5x2.jpg'
#  'T 1580_Page_100.png' 'Modul2 Application Layer Protocols.ppt'
#  '13.Advanced Design.SLDASM' 'Spider-man V2 - T038.cbr' '2256.doc']
# ['jpg' 'docx' 'pptx' 'csv' 'jpg' 'png' 'ppt' 'sldasm' 'cbr' 'doc']
#
#
# Index: 1290
# ['1829.doc'
#  'BLEU - a Method for Automatic Evaluation of Machine Translation.pdf'
#  '2170.pdf' 'StPatricksTodd.jpg' 'Spider-man V2 - T031.cbr'
#  'exoplanets.1363284983.csv' 'Tutor3.SLDPRT' 'exoplanets.1359576499.csv'
#  'Image Enhancements.ppt' 'T 1580_Page_062.png']
# ['doc' 'pdf' 'pdf' 'jpg' 'cbr' 'csv' 'sldprt' 'csv' 'ppt' 'png']
#
#
# Index: 1300
# ['Classes.pptx' 'UE4-AnalyticsET-Android-Shipping-arm64-es2.a'
#  'Крестовина вентилятора ТМЗ.SLDPRT' '2142.doc'
#  'Трубка соединительная 236-1306070-А2.SLDPRT' 'Set Theory 2.pptx'
#  '1976.doc' 'Sequence to Sequence Learning with Deep Neural Networks.pdf'
#  'Tutorial SolidWorks - Eduardo Valiente.SLDPRT'
#  'Spider-man V2 - T132.cbr']
# ['pptx' 'a' 'sldprt' 'doc' 'sldprt' 'pptx' 'doc' 'pdf' 'sldprt' 'cbr']
#
#
# 1300 model Saved.....
#
#
#
# Index: 1310
# ['2079.doc' '2315.pdf' 'GM225S4_07.SLDPRT' '1822.pdf'
#  'Optimization Methods for Deep Learning.pdf' 'DammBMW.jpg' '2282.docx'
#  '12. Sheet Metal Tutorial.SLDPRT' '2172.doc' 'Spider-man V2 - T099.cbr']
# ['doc' 'pdf' 'sldprt' 'pdf' 'pdf' 'jpg' 'docx' 'sldprt' 'doc' 'cbr']
#
#
# Index: 1320
# ['2031.docx' 'Spider-man V2 - T020.cbr'
#  'Alex Graves- Generating Sequences With Recurrent Neural Net.pdf'
#  '2033.doc' 'Spider-man V2 - T136.cbr' '1605.09477.pdf'
#  'exoplanets.1364313396.csv' '1812.doc'
#  'tomb-raider-158071-(www.wallpino.com)-b8ade9d03bc07bca8b7a-2560-1600.jpg'
#  'exoplanets.1378319429.csv']
# ['docx' 'cbr' 'pdf' 'doc' 'cbr' 'pdf' 'csv' 'doc' 'jpg' 'csv']
#
#
# Index: 1330
# ['T 1580_Page_061.png' '1996.docx' '2040.docx' '1851.docx' '362419.jpg'
#  'demande_autorisation_lettre.docx' '2269.doc' '1809.doc' '1966.doc'
#  'EK_Mentese_1a.SLDPRT']
# ['png' 'docx' 'docx' 'docx' 'jpg' 'docx' 'doc' 'doc' 'doc' 'sldprt']
#
#
# Index: 1340
# ['UE4-AIModule-armv7-es2.a' '2004.docx'
#  'Ethics of data representation.pptx' 'libagrmco64.a'
#  'UE4-AnimGraphRuntime-Android-Shipping-armv7-es2.a' '2258.pdf' '1932.pdf'
#  '1912.pdf' '1920.pdf' 'Macdonald57Bug.jpg']
# ['a' 'docx' 'pptx' 'a' 'a' 'pdf' 'pdf' 'pdf' 'pdf' 'jpg']
#
#
# Index: 1350
# ['1876.docx' '2054.doc' '2339.pdf' 'Spider-man V2 - T120.cbr'
#  'EmniyetValfi_1h.SLDPRT' '1971.docx' 'exoplanets.1436203548.csv'
#  'exoplanets.1358113624.csv' 'Spider-man V2 - T033.cbr' '2000.doc']
# ['docx' 'doc' 'pdf' 'cbr' 'sldprt' 'docx' 'csv' 'csv' 'cbr' 'doc']
#
#
# 1350 model Saved.....
#
#
#
# Index: 1360
# ['2299.pdf' 'Fan_1c.SLDPRT' 'exoplanets.1341857673.csv' '1991.docx'
#  'Spider-man V2 - T004.cbr' 'AlcanRabbit.jpg' '1737.docx'
#  'Spider-man V2 - T117.cbr' 'exoplanets.1370635584.csv'
#  'GloVe- Global Vectors for Word Representation.pdf']
# ['pdf' 'sldprt' 'csv' 'docx' 'cbr' 'jpg' 'docx' 'cbr' 'csv' 'pdf']
#
#
# Index: 1370
# ['Spider-man V2 - T137.cbr' '1803.doc' '1846.doc' 'T 1580_Page_078.png'
#  'T 1580_Page_042.png' '2184.doc' 'exoplanets.1375927387.csv'
#  'RRiver04.jpg' 'inroads.jpg'
#  'twin_collective_lever_frame_twin_collective04.SLDPRT']
# ['cbr' 'doc' 'doc' 'png' 'png' 'doc' 'csv' 'jpg' 'jpg' 'sldprt']
#
#
# Index: 1380
# ['2286.docx' 'Image Restoration in spatial domain.ppt'
#  'Spider-man V2 - T130.cbr' 'T 1580_Page_038.png' 'flow ccontrol.ppt'
#  'libadsiis.a' '1884.docx' '2139.doc' 'GM280S4_02.SLDPRT' '2242.docx']
# ['docx' 'ppt' 'cbr' 'png' 'ppt' 'a' 'docx' 'doc' 'sldprt' 'docx']
#
#
# Index: 1390
# ['2039.docx' '1962.doc' '1886.docx' 'libactxprxy.a'
#  'object recognition on shape descriptors.pptx' '1985.doc'
#  'exoplanets.1341128359.csv'
#  'unpaired image-to-image translation using cycle-consistent adversarial networks.pdf']
# ['docx' 'doc' 'docx' 'a' 'pptx' 'doc' 'csv' 'pdf']

# %%
print("Last Saved Model was {}".format(name))

# %%
# !free -mh
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            12G        1.1G        9.8G        904K        1.8G         11G
# Swap:            0B          0B          0B

# %%
x_data.shape

# %%
model.fit(x_data, y_data,epochs=10)
